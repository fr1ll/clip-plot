# %% [raw]
# ---
# output-file: clip_plot.html
# title: TODO
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# # Imports and setup
#
# ### Unconditional imports

# %%
#| echo: false
#| output: asis
show_doc(timestamp)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L41){target="_blank" style="float:right; font-size:smaller"}
#
# ### timestamp
#
# >      timestamp ()
#
# Return a string for printing the current time

# %% [markdown]
# ### Image processing imports
#
# Note that I have removed the "copy-web-only" conditional import path for now
#
# `nbdev` does not like cells to have cells to have code and imports in the same cell:
#
# https://nbdev.fast.ai/getting_started.html#q-what-is-the-warning-found-a-cell-containing-mix-of-imports-and-computations.-please-use-separate-cells
#
# I think this may mean we don't get to do conditional imports. If we find a code path that really should have conditional imports, we can see if there is a workaround. For now, I don't feel "copy web only" is a very important functionality to keep.

# %% [markdown]
# ### Optional install imports

# %% [markdown]
# ## Entry
#
# [`process_images`](https://fr1ll.github.io/clip-plot/clip_plot.html#process_images) will kick off all the main functions for the module

# %%
#| echo: false
#| output: asis
show_doc(preprocess_kwargs)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L143){target="_blank" style="float:right; font-size:smaller"}
#
# ### preprocess_kwargs
#
# >      preprocess_kwargs (**kwargs)
#
# Preprocess incoming key word arguments

# %%
#| echo: false
#| output: asis
show_doc(process_images)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L128){target="_blank" style="float:right; font-size:smaller"}
#
# ### process_images
#
# >      process_images (**kwargs)
#
# Main method for processing user images and metadata

# %%
#| echo: false
#| output: asis
show_doc(copy_web_assets)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L151){target="_blank" style="float:right; font-size:smaller"}
#
# ### copy_web_assets
#
# >      copy_web_assets (**kwargs)
#
# Copy the /web directory from the clipplot source to the users cwd

# %% [markdown]
# ## Images

# %%
#| echo: false
#| output: asis
show_doc(filter_images)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L169){target="_blank" style="float:right; font-size:smaller"}
#
# ### filter_images
#
# >      filter_images (**kwargs)
#
# Main method for filtering images given user metadata (if provided)

# %%
#| echo: false
#| output: asis
show_doc(get_image_paths)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L263){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_image_paths
#
# >      get_image_paths (**kwargs)
#
# Called once to provide a list of image paths--handles IIIF manifest input

# %%
#| echo: false
#| output: asis
show_doc(clean_filename)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L317){target="_blank" style="float:right; font-size:smaller"}
#
# ### clean_filename
#
# >      clean_filename (s, **kwargs)
#
# Given a string that points to a filename, return a clean filename

# %%
#| echo: false
#| output: asis
show_doc(stream_images)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L305){target="_blank" style="float:right; font-size:smaller"}
#
# ### stream_images
#
# >      stream_images (**kwargs)
#
# Read in all images from args[0], a list of image paths

# %%
#| echo: false
#| output: asis
show_doc(get_metadata_list)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L331){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_metadata_list
#
# >      get_metadata_list (**kwargs)
#
# Return a list of objects with image metadata

# %%
#| echo: false
#| output: asis
show_doc(write_metadata)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L360){target="_blank" style="float:right; font-size:smaller"}
#
# ### write_metadata
#
# >      write_metadata (metadata, **kwargs)
#
# Write list `metadata` of objects to disk

# %%
#| echo: false
#| output: asis
show_doc(is_number)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L418){target="_blank" style="float:right; font-size:smaller"}
#
# ### is_number
#
# >      is_number (s)
#
# Return a boolean indicating if a string is a number

# %%
#| echo: false
#| output: asis
show_doc(get_manifest)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L432){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_manifest
#
# >      get_manifest (**kwargs)
#
# Create and return the base object for the manifest output file

# %%
#| echo: false
#| output: asis
show_doc(save_atlas)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L575){target="_blank" style="float:right; font-size:smaller"}
#
# ### save_atlas
#
# >      save_atlas (atlas, out_dir, n)
#
# Save an atlas to disk

# %%
#| echo: false
#| output: asis
show_doc(get_atlas_data)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L515){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_atlas_data
#
# >      get_atlas_data (**kwargs)
#
# Generate and save to disk all atlases to be used for this visualization
# If square, center each cell in an nxn square, else use uniform height

# %%
#| echo: false
#| output: asis
show_doc(get_layouts)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L586){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_layouts
#
# >      get_layouts (**kwargs)
#
# Get the image positions in each projection

# %%
#| echo: false
#| output: asis
show_doc(get_inception_vectors)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L605){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_inception_vectors
#
# >      get_inception_vectors (**kwargs)
#
# Create and return Inception vector representation of Image() instances

# %%
#| echo: false
#| output: asis
show_doc(get_umap_model)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L779){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_umap_model
#
# >      get_umap_model (**kwargs)

# %%
#| echo: false
#| output: asis
show_doc(load_model)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L768){target="_blank" style="float:right; font-size:smaller"}
#
# ### load_model
#
# >      load_model (path)

# %%
#| echo: false
#| output: asis
show_doc(save_model)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L749){target="_blank" style="float:right; font-size:smaller"}
#
# ### save_model
#
# >      save_model (model, path)

# %%
#| echo: false
#| output: asis
show_doc(process_multi_layout_umap)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L682){target="_blank" style="float:right; font-size:smaller"}
#
# ### process_multi_layout_umap
#
# >      process_multi_layout_umap (v, **kwargs)
#
# Create a multi-layout UMAP projection

# %%
#| echo: false
#| output: asis
show_doc(process_single_layout_umap)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L646){target="_blank" style="float:right; font-size:smaller"}
#
# ### process_single_layout_umap
#
# >      process_single_layout_umap (v, **kwargs)
#
# Create a single layout UMAP projection

# %%
#| echo: false
#| output: asis
show_doc(get_umap_layout)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L635){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_umap_layout
#
# >      get_umap_layout (**kwargs)
#
# Get the x,y positions of images passed through a umap projection

# %%
#| echo: false
#| output: asis
show_doc(get_custom_layout)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L854){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_custom_layout
#
# >      get_custom_layout (**kwargs)

# %%
#| echo: false
#| output: asis
show_doc(get_pointgrid_layout)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L840){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_pointgrid_layout
#
# >      get_pointgrid_layout (path, label, **kwargs)
#
# Gridify the positions in `path` and return the path to this new layout

# %%
#| echo: false
#| output: asis
show_doc(get_alphabetic_layout)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L823){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_alphabetic_layout
#
# >      get_alphabetic_layout (**kwargs)
#
# Get the x,y positions of images in a grid projection

# %%
#| echo: false
#| output: asis
show_doc(get_rasterfairy_layout)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L799){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_rasterfairy_layout
#
# >      get_rasterfairy_layout (**kwargs)
#
# Get the x, y position of images passed through a rasterfairy projection

# %% [markdown]
# ### Date Layout

# %%
#| echo: false
#| output: asis
show_doc(round_date)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L990){target="_blank" style="float:right; font-size:smaller"}
#
# ### round_date
#
# >      round_date (date, unit)
#
# Return `date` truncated to the temporal unit specified in `units`

# %%
#| echo: false
#| output: asis
show_doc(date_to_seconds)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L980){target="_blank" style="float:right; font-size:smaller"}
#
# ### date_to_seconds
#
# >      date_to_seconds (date)
#
# Given a datetime object return an integer representation for that datetime

# %%
#| echo: false
#| output: asis
show_doc(datestring_to_date)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L967){target="_blank" style="float:right; font-size:smaller"}
#
# ### datestring_to_date
#
# >      datestring_to_date (datestring)
#
# Given a string representing a date return a datetime object

# %%
#| echo: false
#| output: asis
show_doc(get_date_layout)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L886){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_date_layout
#
# >      get_date_layout (cols=3, bin_units='years', **kwargs)
#
# Get the x,y positions of input images based on their dates
# @param int cols: the number of columns to plot for each bar
# @param str bin_units: the temporal units to use when creating bins

# %% [markdown]
# ### Metadata Layout

# %%
#| echo: false
#| output: asis
show_doc(Box)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1145){target="_blank" style="float:right; font-size:smaller"}
#
# ### Box
#
# >      Box (*args)
#
# Store the width, height, and x, y coords of a box

# %%
#| echo: false
#| output: asis
show_doc(get_categorical_points)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1123){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_categorical_points
#
# >      get_categorical_points (arr, unit_size=None)
#
# Given an array of Box() objects, return a 2D distribution with shape (n_cells, 2)

# %%
#| echo: false
#| output: asis
show_doc(get_categorical_boxes)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1084){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_categorical_boxes
#
# >      get_categorical_boxes (group_counts, margin=2)
#
# @arg [int] group_counts: counts of the number of images in each
#   distinct level within the metadata's caetgories
# @kwarg int margin: space between boxes in the 2D layout
# @returns [Box] an array of Box() objects; one per level in `group_counts`

# %%
#| echo: false
#| output: asis
show_doc(get_categorical_layout)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1020){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_categorical_layout
#
# >      get_categorical_layout (null_category='Other', margin=2, **kwargs)
#
# Return a numpy array with shape (n_points, 2) with the point
# positions of observations in box regions determined by
# each point's category metadata attribute (if applicable)

# %% [markdown]
# ### Geographic Layout

# %%
#| echo: false
#| output: asis
show_doc(process_geojson)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1182){target="_blank" style="float:right; font-size:smaller"}
#
# ### process_geojson
#
# >      process_geojson (geojson_path)
#
# Given a GeoJSON filepath, write a minimal JSON output in lat lng coordinates

# %%
#| echo: false
#| output: asis
show_doc(get_geographic_layout)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1156){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_geographic_layout
#
# >      get_geographic_layout (**kwargs)
#
# Return a 2D array of image positions corresponding to lat, lng coordinates

# %% [markdown]
# ### Helpers

# %%
#| echo: false
#| output: asis
show_doc(write_images)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1327){target="_blank" style="float:right; font-size:smaller"}
#
# ### write_images
#
# >      write_images (**kwargs)
#
# Write all originals and thumbs to the output dir

# %%
#| echo: false
#| output: asis
show_doc(get_heightmap)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1299){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_heightmap
#
# >      get_heightmap (path, label, **kwargs)
#
# Create a heightmap using the distribution of points stored at `path`

# %%
#| echo: false
#| output: asis
show_doc(get_cluster_model)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1287){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_cluster_model
#
# >      get_cluster_model (**kwargs)
#
# Return a model with .fit() method that can be used to cluster input vectors

# %%
#| echo: false
#| output: asis
show_doc(get_hotspots)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1249){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_hotspots
#
# >      get_hotspots (layouts={}, use_high_dimensional_vectors=True, **kwargs)
#
# Return the stable clusters from the condensed tree of connected components from the density graph

# %%
#| echo: false
#| output: asis
show_doc(read_json)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1240){target="_blank" style="float:right; font-size:smaller"}
#
# ### read_json
#
# >      read_json (path, **kwargs)
#
# Read and return the json object written by the current process at `path`

# %%
#| echo: false
#| output: asis
show_doc(write_json)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1225){target="_blank" style="float:right; font-size:smaller"}
#
# ### write_json
#
# >      write_json (path, obj, **kwargs)
#
# Write json object `obj` to disk and return the path to that file

# %%
#| echo: false
#| output: asis
show_doc(round_floats)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1220){target="_blank" style="float:right; font-size:smaller"}
#
# ### round_floats
#
# >      round_floats (obj, digits=5)
#
# Return 2D array obj with rounded float precision

# %%
#| echo: false
#| output: asis
show_doc(write_layout)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1209){target="_blank" style="float:right; font-size:smaller"}
#
# ### write_layout
#
# >      write_layout (path, obj, **kwargs)
#
# Write layout json `obj` to disk and return the path to the saved file

# %%
#| echo: false
#| output: asis
show_doc(get_path)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1199){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_path
#
# >      get_path (*args, **kwargs)
#
# Return the path to a JSON file with conditional gz extension

# %%
#| echo: false
#| output: asis
show_doc(get_version)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1350){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_version
#
# >      get_version ()
#
# Return the version of clipplot installed
# Hardcoded for now

# %%
#| echo: false
#| output: asis
show_doc(Image)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1359){target="_blank" style="float:right; font-size:smaller"}
#
# ### Image
#
# >      Image (*args, **kwargs)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# # Parse the command-line arguments

# %%
#| echo: false
#| output: asis
show_doc(parse)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1402){target="_blank" style="float:right; font-size:smaller"}
#
# ### parse
#
# >      parse (args:Optional[dict]=None)
#
# Read command line args and begin data processing

# %%
#| echo: false
#| output: asis
show_doc(get_clip_plot_root)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1553){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_clip_plot_root
#
# >      get_clip_plot_root ()
