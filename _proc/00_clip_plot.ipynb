# %% [raw]
# ---
# output-file: clip_plot.html
# title: TODO
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# # Imports and setup
#
# ### Unconditional imports

# %%
#| echo: false
#| output: asis
show_doc(timestamp)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L43){target="_blank" style="float:right; font-size:smaller"}
#
# ### timestamp
#
# >      timestamp ()
#
# Return a string for printing the current time

# %% [markdown]
# ### Image processing imports
#
# Note that I have removed the "copy-web-only" conditional import path for now
#
# `nbdev` does not like cells to have cells to have code and imports in the same cell:
#
# https://nbdev.fast.ai/getting_started.html#q-what-is-the-warning-found-a-cell-containing-mix-of-imports-and-computations.-please-use-separate-cells
#
# I think this may mean we don't get to do conditional imports. If we find a code path that really should have conditional imports, we can see if there is a workaround. For now, I don't feel "copy web only" is a very important functionality to keep.

# %% [markdown]
# ### Optional install imports

# %% [markdown]
# ## Entry
#
# [`process_images`](https://fr1ll.github.io/clip-plot/clip_plot.html#process_images) will kick off all the main functions for the module

# %%
#| echo: false
#| output: asis
show_doc(preprocess_kwargs)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L154){target="_blank" style="float:right; font-size:smaller"}
#
# ### preprocess_kwargs
#
# >      preprocess_kwargs (**kwargs)
#
# Preprocess incoming key word arguments
# Converts n_neighbors and min_dist arguments into a list
#
# Args:
#     n_neighbors (int, list[int], default = [15])
#     min_dist (int, list[int], default = [0.01])
#
# Notes:
#     Convenient hook for preprocessing arguments

# %%
#| echo: false
#| output: asis
show_doc(process_images)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L132){target="_blank" style="float:right; font-size:smaller"}
#
# ### process_images
#
# >      process_images (**kwargs)
#
# Main method for processing user images and metadata

# %%
#| echo: false
#| output: asis
show_doc(copy_web_assets)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L172){target="_blank" style="float:right; font-size:smaller"}
#
# ### copy_web_assets
#
# >      copy_web_assets (out_dir:str)
#
# Copy the /web directory from the clipplot source to the users cwd.
# Copies version number into assets.
#
# Args:
#     out_dir (str): directory to copy web assets
#
# Returns:
#     None

# %% [markdown]
# ## Images

# %%
#| echo: false
#| output: asis
show_doc(filter_images)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L198){target="_blank" style="float:right; font-size:smaller"}
#
# ### filter_images
#
# >      filter_images (**kwargs)
#
# Main method for filtering images given user metadata (if provided)
#
# -Validate image:
#     Loading (done by stream_images and Images)
#     Size
#     resizing
#     oblong
#
# -Compare against metadata
#
# Args:
#     atlas_size (int, default = 2048)
#     cell_size (int, default = 32)
#     lod_cell_height (int, default = 128)
#     shuffle (Optional[bool], default = False)
#
# Returns:
#     images (list[str])
#     metadata (list[dict])
#
# Notes:
#     Assumes 'filename' is provided in metadata
#     Convoluted compiling of metadata
#     Should All Validation should belong to Image class?
#     Need to split function

# %%
#| echo: false
#| output: asis
show_doc(get_image_paths)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L306){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_image_paths
#
# >      get_image_paths (images:str, out_dir:str)
#
# Called once to provide a list of image paths--handles IIIF manifest input.
#
# args:
#     images (str): directory location of images.
#     out_dir (str): output directory for downloaded IIIF files.
#
# returns:
#     image_paths list(str): list of image paths.
#
# Note:
#     Old/previous images are not deleted from IIIF directory.
#
# Todo:
#     Consider separate function that handles IIIF images
#     from glob images.

# %%
#| echo: false
#| output: asis
show_doc(clean_filename)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L362){target="_blank" style="float:right; font-size:smaller"}
#
# ### clean_filename
#
# >      clean_filename (s, **kwargs)
#
# Given a string that points to a filename, return a clean filename
#
# Args:
#     s (str): filename path
#
# Returns:
#     s (str): clean file name
#
# Notes:
#     kwargs is not used at all

# %%
#| echo: false
#| output: asis
show_doc(get_metadata_list)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L387){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_metadata_list
#
# >      get_metadata_list (meta_dir:str)
#
# Return a list of objects with image metadata.
#
# Will create 'tags' key if 'category' is in metadata
# but not 'tags'.
#
# Args:
#     metadata (str, default = None): Metadata location
#
# Returns:
#     l (List[dict]): List of metadata
#
# Notes:
#     No check for 'filename' is performed
#
# Todo:
#     Think about separating .csv and json functionality.
#     Can we use pandas numpy to process csv?

# %%
#| echo: false
#| output: asis
show_doc(write_metadata)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L434){target="_blank" style="float:right; font-size:smaller"}
#
# ### write_metadata
#
# >      write_metadata (metadata, **kwargs)
#
# Write list `metadata` of objects to disk
#
# Args:
#     metadata (list[dict])
#     out_dir (str)
#
#     subfunctions:
#         write_json():
#             gzip (Optional[bool]):
#             encoding (Optional[str]): Required if gzip is provided
#                 default = 'utf8'
#
# Returns:
#     None
#
# Notes:
#     Improve variable naming

# %%
#| echo: false
#| output: asis
show_doc(is_number)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L516){target="_blank" style="float:right; font-size:smaller"}
#
# ### is_number
#
# >      is_number (s)
#
# Return a boolean indicating if a string is a number
#
# Args:
#     s (Any); Value to be checked
#
# Returns:
#     bool

# %%
#| echo: false
#| output: asis
show_doc(get_manifest)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L538){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_manifest
#
# >      get_manifest (**kwargs)
#
# Create and return the base object for the manifest output file
#
# Args:
#     atlas_dir (str)
#     image_paths (str)
#     plot_id (str, default = str(uuid.uuid1()))
#     out_dir (str)
#     metadata (list[dict]): Only checking if provided
#     gzip (bool, default = False)
#     atlas_size (int, default = 2048)
#     cell_size (int, default = 32)
#     lod_cell_height (int, default = 128)
#
#     Need to check subfunctions
#
# Returns:
#     None
#
# Notes:
#     Original description is inadequate
#     Function is to big (god function)

# %%
#| echo: false
#| output: asis
show_doc(save_atlas)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L720){target="_blank" style="float:right; font-size:smaller"}
#
# ### save_atlas
#
# >      save_atlas (atlas, out_dir, n)
#
# Save an atlas to disk

# %%
#| echo: false
#| output: asis
show_doc(get_atlas_data)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L644){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_atlas_data
#
# >      get_atlas_data (**kwargs)
#
# Generate and save to disk all atlases to be used for this visualization
# If square, center each cell in an nxn square, else use uniform height
#
# Args:
#     out_dir (str)
#     plot_id (str, default = str(uuid.uuid1()))
#     use_cache (bool, default = False)
#     shuffle (Optional[bool], default = False)
#     atlas_size (int, default = 2048)
#     cell_size (int, default = 32)
#     lod_cell_height (int, default = 128)
#
# Returns:
#     out_dir (str): Atlas location
#
# Notes:

# %%
#| echo: false
#| output: asis
show_doc(get_layouts)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L731){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_layouts
#
# >      get_layouts (**kwargs)
#
# Get the image positions in each projection

# %%
#| echo: false
#| output: asis
show_doc(get_inception_vectors)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L750){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_inception_vectors
#
# >      get_inception_vectors (**kwargs)
#
# Create and return Inception vector representation of Image() instances

# %%
#| echo: false
#| output: asis
show_doc(get_umap_model)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L924){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_umap_model
#
# >      get_umap_model (**kwargs)

# %%
#| echo: false
#| output: asis
show_doc(load_model)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L913){target="_blank" style="float:right; font-size:smaller"}
#
# ### load_model
#
# >      load_model (path)

# %%
#| echo: false
#| output: asis
show_doc(save_model)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L894){target="_blank" style="float:right; font-size:smaller"}
#
# ### save_model
#
# >      save_model (model, path)

# %%
#| echo: false
#| output: asis
show_doc(process_multi_layout_umap)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L827){target="_blank" style="float:right; font-size:smaller"}
#
# ### process_multi_layout_umap
#
# >      process_multi_layout_umap (v, **kwargs)
#
# Create a multi-layout UMAP projection

# %%
#| echo: false
#| output: asis
show_doc(process_single_layout_umap)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L791){target="_blank" style="float:right; font-size:smaller"}
#
# ### process_single_layout_umap
#
# >      process_single_layout_umap (v, **kwargs)
#
# Create a single layout UMAP projection

# %%
#| echo: false
#| output: asis
show_doc(get_umap_layout)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L780){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_umap_layout
#
# >      get_umap_layout (**kwargs)
#
# Get the x,y positions of images passed through a umap projection

# %%
#| echo: false
#| output: asis
show_doc(get_custom_layout)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L999){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_custom_layout
#
# >      get_custom_layout (**kwargs)

# %%
#| echo: false
#| output: asis
show_doc(get_pointgrid_layout)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L985){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_pointgrid_layout
#
# >      get_pointgrid_layout (path, label, **kwargs)
#
# Gridify the positions in `path` and return the path to this new layout

# %%
#| echo: false
#| output: asis
show_doc(get_alphabetic_layout)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L968){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_alphabetic_layout
#
# >      get_alphabetic_layout (**kwargs)
#
# Get the x,y positions of images in a grid projection

# %%
#| echo: false
#| output: asis
show_doc(get_rasterfairy_layout)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L944){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_rasterfairy_layout
#
# >      get_rasterfairy_layout (**kwargs)
#
# Get the x, y position of images passed through a rasterfairy projection

# %% [markdown]
# ### Date Layout

# %%
#| echo: false
#| output: asis
show_doc(round_date)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1135){target="_blank" style="float:right; font-size:smaller"}
#
# ### round_date
#
# >      round_date (date, unit)
#
# Return `date` truncated to the temporal unit specified in `units`

# %%
#| echo: false
#| output: asis
show_doc(date_to_seconds)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1125){target="_blank" style="float:right; font-size:smaller"}
#
# ### date_to_seconds
#
# >      date_to_seconds (date)
#
# Given a datetime object return an integer representation for that datetime

# %%
#| echo: false
#| output: asis
show_doc(datestring_to_date)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1112){target="_blank" style="float:right; font-size:smaller"}
#
# ### datestring_to_date
#
# >      datestring_to_date (datestring)
#
# Given a string representing a date return a datetime object

# %%
#| echo: false
#| output: asis
show_doc(get_date_layout)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1031){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_date_layout
#
# >      get_date_layout (cols=3, bin_units='years', **kwargs)
#
# Get the x,y positions of input images based on their dates
# @param int cols: the number of columns to plot for each bar
# @param str bin_units: the temporal units to use when creating bins

# %% [markdown]
# ### Metadata Layout

# %%
#| echo: false
#| output: asis
show_doc(Box)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1290){target="_blank" style="float:right; font-size:smaller"}
#
# ### Box
#
# >      Box (*args)
#
# Store the width, height, and x, y coords of a box

# %%
#| echo: false
#| output: asis
show_doc(get_categorical_points)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1268){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_categorical_points
#
# >      get_categorical_points (arr, unit_size=None)
#
# Given an array of Box() objects, return a 2D distribution with shape (n_cells, 2)

# %%
#| echo: false
#| output: asis
show_doc(get_categorical_boxes)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1229){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_categorical_boxes
#
# >      get_categorical_boxes (group_counts, margin=2)
#
# @arg [int] group_counts: counts of the number of images in each
#   distinct level within the metadata's caetgories
# @kwarg int margin: space between boxes in the 2D layout
# @returns [Box] an array of Box() objects; one per level in `group_counts`

# %%
#| echo: false
#| output: asis
show_doc(get_categorical_layout)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1165){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_categorical_layout
#
# >      get_categorical_layout (null_category='Other', margin=2, **kwargs)
#
# Return a numpy array with shape (n_points, 2) with the point
# positions of observations in box regions determined by
# each point's category metadata attribute (if applicable)

# %% [markdown]
# ### Geographic Layout

# %%
#| echo: false
#| output: asis
show_doc(process_geojson)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1327){target="_blank" style="float:right; font-size:smaller"}
#
# ### process_geojson
#
# >      process_geojson (geojson_path)
#
# Given a GeoJSON filepath, write a minimal JSON output in lat lng coordinates

# %%
#| echo: false
#| output: asis
show_doc(get_geographic_layout)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1301){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_geographic_layout
#
# >      get_geographic_layout (**kwargs)
#
# Return a 2D array of image positions corresponding to lat, lng coordinates

# %% [markdown]
# ### Helpers

# %%
#| echo: false
#| output: asis
show_doc(write_images)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1472){target="_blank" style="float:right; font-size:smaller"}
#
# ### write_images
#
# >      write_images (**kwargs)
#
# Write all originals and thumbs to the output dir

# %%
#| echo: false
#| output: asis
show_doc(get_heightmap)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1444){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_heightmap
#
# >      get_heightmap (path, label, **kwargs)
#
# Create a heightmap using the distribution of points stored at `path`

# %%
#| echo: false
#| output: asis
show_doc(get_cluster_model)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1432){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_cluster_model
#
# >      get_cluster_model (**kwargs)
#
# Return a model with .fit() method that can be used to cluster input vectors

# %%
#| echo: false
#| output: asis
show_doc(get_hotspots)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1394){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_hotspots
#
# >      get_hotspots (layouts={}, use_high_dimensional_vectors=True, **kwargs)
#
# Return the stable clusters from the condensed tree of connected components from the density graph

# %%
#| echo: false
#| output: asis
show_doc(read_json)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1385){target="_blank" style="float:right; font-size:smaller"}
#
# ### read_json
#
# >      read_json (path, **kwargs)
#
# Read and return the json object written by the current process at `path`

# %%
#| echo: false
#| output: asis
show_doc(write_json)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1370){target="_blank" style="float:right; font-size:smaller"}
#
# ### write_json
#
# >      write_json (path, obj, **kwargs)
#
# Write json object `obj` to disk and return the path to that file

# %%
#| echo: false
#| output: asis
show_doc(round_floats)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1365){target="_blank" style="float:right; font-size:smaller"}
#
# ### round_floats
#
# >      round_floats (obj, digits=5)
#
# Return 2D array obj with rounded float precision

# %%
#| echo: false
#| output: asis
show_doc(write_layout)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1354){target="_blank" style="float:right; font-size:smaller"}
#
# ### write_layout
#
# >      write_layout (path, obj, **kwargs)
#
# Write layout json `obj` to disk and return the path to the saved file

# %%
#| echo: false
#| output: asis
show_doc(get_path)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1344){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_path
#
# >      get_path (*args, **kwargs)
#
# Return the path to a JSON file with conditional gz extension

# %%
#| echo: false
#| output: asis
show_doc(get_version)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1495){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_version
#
# >      get_version ()
#
# Return the version of clipplot installed
# Hardcoded for now

# %%
#| echo: false
#| output: asis
show_doc(Image)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1504){target="_blank" style="float:right; font-size:smaller"}
#
# ### Image
#
# >      Image (*args, **kwargs)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# # Parse the command-line arguments

# %%
#| echo: false
#| output: asis
show_doc(parse)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1620){target="_blank" style="float:right; font-size:smaller"}
#
# ### parse
#
# >      parse (args:Optional[dict]=None)
#
# Read command line args and begin data processing

# %%
#| echo: false
#| output: asis
show_doc(get_clip_plot_root)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1772){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_clip_plot_root
#
# >      get_clip_plot_root ()

# %% [markdown]
# ## Removing some Keras functions

# %%
#| echo: false
#| output: asis
show_doc(save_image)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1864){target="_blank" style="float:right; font-size:smaller"}
#
# ### save_image
#
# >      save_image (path:str, x:<built-infunctionarray>)
#
# Saves an image stored as a Numpy array to a path or file object.
#
# Args:
#     path: Path or file object.
#     x: Numpy array.

# %%
#| echo: false
#| output: asis
show_doc(array_to_image)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1822){target="_blank" style="float:right; font-size:smaller"}
#
# ### array_to_image
#
# >      array_to_image (x:<built-infunctionarray>)
#
# Converts a 3D Numpy array to a PIL Image instance.
#
# Args:
#     x: Input data, in any form that can be converted to a Numpy array.
#
# Returns:
#     A PIL Image instance.
#
# Raises:
#     ValueError: if invalid `x` or `data_format` is passed.

# %%
#| echo: false
#| output: asis
show_doc(image_to_array)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1796){target="_blank" style="float:right; font-size:smaller"}
#
# ### image_to_array
#
# >      image_to_array (img:PIL.Image.Image)
#
# Converts a PIL Image instance to a Numpy array.
#
# Args:
#     img: Input PIL Image instance.
#
# Returns:
#     A 3D Numpy array.
#
# Raises:
#     ValueError: if invalid `img` or `data_format` is passed.

# %%
#| echo: false
#| output: asis
show_doc(load_image)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1786){target="_blank" style="float:right; font-size:smaller"}
#
# ### load_image
#
# >      load_image (path:str)

# %% [markdown]
# ## Carlo's Test Functions

# %%
#| echo: false
#| output: asis
show_doc(test_no_meta_dir)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1931){target="_blank" style="float:right; font-size:smaller"}
#
# ### test_no_meta_dir
#
# >      test_no_meta_dir (config)

# %%
#| echo: false
#| output: asis
show_doc(test_butterfly_missing_meta)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1917){target="_blank" style="float:right; font-size:smaller"}
#
# ### test_butterfly_missing_meta
#
# >      test_butterfly_missing_meta (config)

# %%
#| echo: false
#| output: asis
show_doc(test_butterfly)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1903){target="_blank" style="float:right; font-size:smaller"}
#
# ### test_butterfly
#
# >      test_butterfly (config)

# %%
#| echo: false
#| output: asis
show_doc(test_butterfly_duplicate)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1889){target="_blank" style="float:right; font-size:smaller"}
#
# ### test_butterfly_duplicate
#
# >      test_butterfly_duplicate (config)

# %%
#| echo: false
#| output: asis
show_doc(test_iiif)
# Out:
# ---
#
# [source](https://github.com/fr1ll/clip-plot/blob/main/clip_plot/clip_plot.py#L1875){target="_blank" style="float:right; font-size:smaller"}
#
# ### test_iiif
#
# >      test_iiif (config)
